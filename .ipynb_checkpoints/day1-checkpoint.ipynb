# %%
pip install pyforest
# Out:
# ...
#
#   Using cached pyforest-1.1.0.tar.gz (15 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14630 sha256=1a4f2e06d10f7594dd7ae3ee64e44b283103e608849e8776befb11b6ec8a1bcf
#   Stored in directory: c:\users\malle pranav dheeraj\appdata\local\pip\cache\wheels\ec\0b\21\11e15b81d41c6ea60c8c26a49c885f75abd45bfa0456ef4ba7
# Successfully built pyforest
# ...

# %%
from pyforest import*
lazy_imports()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyforest import*
#       2 lazy_imports()
#
# ModuleNotFoundError: No module named 'pyforest'

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 108.9 kB/s eta 0:00:01
#      ------------ ------------------------- 20.5/61.0 kB 108.9 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 163.4 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 187.0 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 171.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB 991.0 kB/s eta 0:00:16
#    ---------------------------------------- 0.1/15.5 MB 1.7 MB/s eta 0:00:09
#     --------------------------------------- 0.2/15.5 MB 1.7 MB/s eta 0:00:09
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
pip install seaborn
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
Train_data=pd.read_csv('C:/projectk/salesprediction/train.csv' )
Test_data=pd.read_csv("C:/projectk/salesprediction/test.csv")

# %%
Train_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
Test_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...
